# %% [markdown]
# **Analyse of ouor family.. date and palce of birth**

# %%
import pandas as pd  # Práce s daty
import networkx as nx  # Tvorba grafové struktury (rodokmen)
import plotly.express as px  # Interaktivní vizualizace
import dash  # Webový framework pro interaktivní vizualizace
import folium  # Práce s mapami (pokud chceš i geografická data)
import keyboard  # Zachytávání klávesových zkratek
from dash_extensions import Keyboard  # Rozšíření pro klávesové zkratky v Dash

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import time

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců (odstranění mezer, převedení na malá písmena)
df.columns = df.columns.str.strip().str.lower()
df_relations.columns = df_relations.columns.str.strip().str.lower()

# Oprava názvu sloupce 'datum narození'
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod sloupce Datum narození na datetime a seřazení podle něj
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')

# Sloučení obou datasetů
df_combined = pd.concat([df[['jméno', 'datum_narozeni']], df_relations[['jméno', 'datum_narozeni']]])
df_combined = df_combined.sort_values('datum_narozeni').reset_index(drop=True)

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("Časová osa narození rodiny"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
])

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df_combined.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y='jméno',
                     text='jméno', title="Časová osa narození")
    fig.update_traces(textposition='top center')
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import time

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců (odstranění mezer, převedení na malá písmena)
df.columns = df.columns.str.strip().str.lower()
df_relations.columns = df_relations.columns.str.strip().str.lower()

# Oprava názvu sloupce 'datum narození'
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod sloupce Datum narození na datetime a seřazení podle něj
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')

# Sloučení obou datasetů
df_combined = pd.concat([df[['jméno', 'datum_narozeni']], df_relations[['jméno', 'datum_narozeni']]])
df_combined = df_combined.sort_values('datum_narozeni').reset_index(drop=True)

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("Časová osa narození rodiny"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
])

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df_combined.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y=[0] * len(data_to_show),
                     text='jméno', title="Časová osa narození")
    fig.update_traces(textposition='top center')
    fig.update_layout(yaxis=dict(showticklabels=False, title=""))
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import time

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců (odstranění mezer, převedení na malá písmena)
df.columns = df.columns.str.strip().str.lower()
df_relations.columns = df_relations.columns.str.strip().str.lower()

# Oprava názvu sloupce 'datum narození'
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod sloupce Datum narození na datetime a seřazení podle něj
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')

# Sloučení obou datasetů
df_combined = pd.concat([df[['jméno', 'datum_narozeni']], df_relations[['jméno', 'datum_narozeni']]])
df_combined = df_combined.sort_values('datum_narozeni').reset_index(drop=True)

# Přidání střídavého umístění jmen na ose Y
df_combined['y_pos'] = [0.5 if i % 2 == 0 else -0.5 for i in range(len(df_combined))]

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("Časová osa narození rodiny"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
], style={'backgroundColor': '#222', 'color': 'white', 'textAlign': 'center', 'padding': '20px'})

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df_combined.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y='y_pos',
                     text='jméno', title="Časová osa narození",
                     template='plotly_dark')
    fig.update_traces(textposition='top center')
    
    fig.update_layout(
        yaxis=dict(showticklabels=False, title="", zeroline=True, zerolinewidth=2, zerolinecolor='white'),
        xaxis=dict(title="Datum narození"),
        plot_bgcolor='#222',
        paper_bgcolor='#222',
        showlegend=False
    )
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců (odstranění mezer, převedení na malá písmena)
df.columns = df.columns.str.strip().str.lower()
df_relations.columns = df_relations.columns.str.strip().str.lower()

# Oprava názvu sloupce 'datum narození'
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod sloupce Datum narození na datetime a seřazení podle něj
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')

# Sloučení obou datasetů
df_combined = pd.concat([df[['jméno', 'datum_narozeni']], df_relations[['jméno', 'datum_narozeni']]])
df_combined = df_combined.sort_values('datum_narozeni').reset_index(drop=True)

# Přidání střídavého umístění jmen na ose Y
df_combined['y_pos'] = [0.5 if i % 2 == 0 else -0.5 for i in range(len(df_combined))]

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("ČASOVÁ OSA NAŠÍ RODINY"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
], style={'backgroundColor': '#222', 'color': 'white', 'textAlign': 'center', 'padding': '20px'})

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df_combined.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y='y_pos',
                     text='jméno', title="Časová osa narození",
                     template='plotly_dark')
    
    fig.update_traces(
        textposition='top center',
        marker=dict(size=10)  # Zvětšení bodů
    )
    
    fig.update_layout(
        yaxis=dict(showticklabels=False, title="", zeroline=True, zerolinewidth=2, zerolinecolor='white'),
        xaxis=dict(title="Datum narození", dtick="M12"),  # Dělení osy X po roce
        plot_bgcolor='#222',
        paper_bgcolor='#222',
        showlegend=False
    )
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 67, in update_graph(n_clicks_next=7, n_clicks_prev=0)
#      64 data_to_show = df_relations.iloc[:n_to_show]
#      66 # Vytvoření scatter grafu s barvami puntíků podle 'dot_color'
# ---> 67 fig = px.scatter(data_to_show, x='datum_narozeni', y='y_pos',
#         data_to_show =    počet  id_1  id_2  id_3  id_4    jméno    příjmení datum_narozeni adresa  \
# 0      1   1.0   2.0   NaN   NaN     Jana   Pawlasová     1967-04-26    NaN
# 1      2   1.0   2.0   NaN   NaN   Martin      Pawlas     1968-03-01    NaN
# 2      3   3.0   4.0   NaN   NaN      Eva   Prokopová     1958-10-26    NaN
# 3      4   3.0   4.0   NaN   NaN     Jiří      Prokop     1955-04-30    NaN
# 4      5   9.0   NaN   NaN   NaN  Vlastík     Rybařík     1969-11-20    NaN
# ...

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import time

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců (odstranění mezer, převedení na malá písmena)
df.columns = df.columns.str.strip().str.lower()
df_relations.columns = df_relations.columns.str.strip().str.lower()

# Oprava názvu sloupce 'datum narození'
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod sloupce Datum narození na datetime a vytvoření sloupce 'rok'
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')
df['rok'] = df['datum_narozeni'].dt.year

df_relations['rok'] = df_relations['datum_narozeni'].dt.year

# Odstranění řádků s NaN v roce
df = df.dropna(subset=['rok'])
df_relations = df_relations.dropna(subset=['rok'])

# Konverze roku na integer
df['rok'] = df['rok'].astype(int)
df_relations['rok'] = df_relations['rok'].astype(int)

# Sloučení obou datasetů
df_combined = pd.concat([df[['jméno', 'příjmení', 'datum_narozeni', 'rok']], df_relations[['jméno', 'příjmení', 'datum_narozeni', 'rok']]])
df_combined = df_combined.sort_values('datum_narozeni').reset_index(drop=True)

# Vytvoření popisku jména a příjmení
df_combined['popisek'] = df_combined['jméno'] + ' ' + df_combined['příjmení']

# Vytvoření záchytných bodů pro jednotlivé roky
min_rok, max_rok = df_combined['rok'].min(), df_combined['rok'].max()
years_df = pd.DataFrame({'rok': list(range(min_rok, max_rok + 1)), 'datum_narozeni': [df_combined['datum_narozeni'].min()] * (max_rok - min_rok + 1)})

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("Časová osa narození rodiny"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
], style={'backgroundColor': '#444', 'color': 'white', 'textAlign': 'center', 'padding': '20px'})

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df_combined.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y='rok',
                     text='popisek', title="Časová osa narození",
                     template='plotly_dark')
    
    # Přidání záchytných bodů pro roky
    for year in years_df['rok']:
        fig.add_shape(
            type="line",
            x0=years_df['datum_narozeni'].min(), x1=years_df['datum_narozeni'].max(),
            y0=year, y1=year,
            line=dict(color="gray", width=0.5, dash="dot")
        )
    
    fig.update_layout(
    yaxis=dict(
        title="Rok narození",
        tickmode="array",
        tickvals=list(range(min_rok, max_rok + 1)),  # Hodnoty na ose Y
        ticktext=[str(year) for year in range(min_rok, max_rok + 1)]  # Popisky k hodnotám
    ),
        xaxis=dict(title="Datum narození"),
        plot_bgcolor='#555',
        paper_bgcolor='#555'
    )
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# POSLEDNÍ VERZE

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců (odstranění mezer, převedení na malá písmena)
df.columns = df.columns.str.strip().str.lower()
df_relations.columns = df_relations.columns.str.strip().str.lower()

# Oprava názvu sloupce 'datum narození'
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod sloupce datum narození na datetime a seřazení podle něj
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')

# Kontrola přítomnosti sloupce 'pohlaví'
if 'pohlaví' not in df.columns:
    df['pohlaví'] = 'neuvedeno'
if 'pohlaví' not in df_relations.columns:
    df_relations['pohlaví'] = 'neuvedeno'

# Sloučení obou datasetů
df_combined = pd.concat([
    df[['jméno', 'příjmení', 'datum_narozeni', 'pohlaví']],
    df_relations[['jméno', 'příjmení', 'datum_narozeni', 'pohlaví']]
])
df_combined = df_combined.sort_values('datum_narozeni').reset_index(drop=True)

# Spojení jména a příjmení pro unikátní identifikaci
df_combined['full_name'] = df_combined['jméno'] + ' ' + df_combined['příjmení']

# Přidání střídavého umístění jmen na ose Y podle pohlaví
male_offset = 0.5
female_offset = -0.5
step = 0.3  # Posun pro lepší čitelnost

df_combined['y_pos'] = [
    (i * step + male_offset) if row.pohlaví == 'm' else (i * step + female_offset)
    for i, row in enumerate(df_combined.itertuples())
]

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("Časová osa narození rodiny"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
], style={'backgroundColor': '#222', 'color': 'white', 'textAlign': 'center', 'padding': '20px'})

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df_combined.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y='y_pos',
                     text='full_name', title="Časová osa narození",
                     template='plotly_dark')
    
    fig.update_traces(
        textposition='top center',
        marker=dict(size=10)  # Zvětšení bodů
    )
    
    fig.update_layout(
        yaxis=dict(showticklabels=False, title="", zeroline=True, zerolinewidth=2, zerolinecolor='white'),
        xaxis=dict(title="Datum narození", dtick="M12"),  # Dělení osy X po roce
        plot_bgcolor='#222',
        paper_bgcolor='#222'
    )
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h1><b>FINÁLNÍ PODOBA KODU - Vnoučata a pravnoučata

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df = pd.read_excel(file_path, sheet_name='Vnoučata a pravnoučata')

# Oprava názvů sloupců
df.columns = df.columns.str.strip().str.lower()
df.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod datového typu
df['datum_narozeni'] = pd.to_datetime(df['datum_narozeni'], errors='coerce')

# Přidání sloupce s celým jménem
df['full_name'] = df['jméno'] + ' ' + df['příjmení']

# Podmínka pro barvy bodů
df['color'] = df['příjmení'].astype(str).apply(lambda x: 'lightred' if x.endswith('ová') else 'lightcoral')

# Vytvoření souřadnic Y podle pohlaví
male_offset = 0.5
female_offset = -0.5
step = 0.3
df = df.sort_values(by='datum_narozeni').reset_index(drop=True)
df['y_pos'] = [
    (i * step + male_offset) if getattr(row, 'pohlaví', '') == 'm' else (i * step + female_offset)
    for i, row in enumerate(df.itertuples(index=False, name=None))
]

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

app.layout = html.Div([
    html.H1("Časová osa narození - Vnoučata a pravnoučata"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0)
], style={'backgroundColor': '#222', 'color': 'white', 'textAlign': 'center', 'padding': '20px'})

@app.callback(
    Output('timeline-graph', 'figure'),
    Input('next-button', 'n_clicks')
)
def update_graph(n_clicks):
    if n_clicks == 0:
        return px.scatter()
    
    data_to_show = df.iloc[:n_clicks]
    
    fig = px.scatter(data_to_show, x='datum_narozeni', y='y_pos',
                     text='full_name', title="Časová osa narození",
                     color='color',  # Nastavení barev
                     template='plotly_dark',
                     color_discrete_map={'lightblue': 'lightblue', 'lightred': 'lightcoral'})  # Oprava barvy
    
    fig.update_traces(textposition='top center', marker=dict(size=10))
    
    fig.update_layout(
        yaxis=dict(showticklabels=False, title=""),
        xaxis=dict(title="Datum narození", dtick="M12"),
        plot_bgcolor='#222',
        paper_bgcolor='#222'
    )
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8050)

# %% [markdown]
# <h1><b> FINALNÍ PODOBA KODU - Děti rodiče

# %%
import pandas as pd
import plotly.express as px
import dash
from dash import dcc, html
from dash.dependencies import Input, Output

# Načtení dat
file_path = r"C:\Users\jpawlas\Desktop\ra.xlsx"
df_relations = pd.read_excel(file_path, sheet_name='Děti-rodiče')

# Oprava názvů sloupců
df_relations.columns = df_relations.columns.str.strip().str.lower()
df_relations.rename(columns={'datum narození': 'datum_narozeni'}, inplace=True)

# Převod datového typu
df_relations['datum_narozeni'] = pd.to_datetime(df_relations['datum_narozeni'], errors='coerce')

# Přidání sloupce s celým jménem
df_relations['full_name'] = df_relations['jméno'] + ' ' + df_relations['příjmení']

# Vytvoření souřadnic Y podle pohlaví
male_offset = 0.5
female_offset = -0.5
step = 0.3

# Použití _asdict pro správný přístup k hodnotám sloupců
df_relations['y_pos'] = [
    (i * step + male_offset) if row._asdict()['pohlavi'] == 'm' else (i * step + female_offset)
    for i, row in enumerate(df_relations.itertuples())
]

# Seřazení dat podle data narození (chronologicky)
df_relations = df_relations.sort_values(by='datum_narozeni')

# Přidání sloupce pro barvu bodu (červený pokud jméno končí na "ová")
df_relations['dot_color'] = df_relations['full_name'].apply(
    lambda x: 'lightred' if isinstance(x, str) and x.endswith('ová') else 'lightblue'
)

# Inicializace Dash aplikace
app = dash.Dash(__name__, suppress_callback_exceptions=True)

# Layout s tlačítky
app.layout = html.Div([
    html.H1("Časová osa narození - Děti a rodiče"),
    dcc.Graph(id='timeline-graph'),
    html.Button("Další", id='next-button', n_clicks=0),
    html.Button("Zpět", id='prev-button', n_clicks=0)
], style={'backgroundColor': '#222', 'color': 'white', 'textAlign': 'center', 'padding': '20px'})

@app.callback(
    Output('timeline-graph', 'figure'),
    [Input('next-button', 'n_clicks'),
     Input('prev-button', 'n_clicks')]
)
def update_graph(n_clicks_next, n_clicks_prev):
    # Počet zobrazených bodů (dynamické)
    n_to_show = n_clicks_next - n_clicks_prev
    
    # Pokud není žádný bod k zobrazení, vrátíme prázdný scatter
    if n_to_show <= 0:
        return px.scatter()

    data_to_show = df_relations.iloc[:n_to_show]
    
    # Vytvoření scatter grafu s barvami puntíků podle 'dot_color'
    fig = px.scatter(data_to_show, x='datum_narozeni', y='y_pos',
                     text='full_name', title="Časová osa narození dětí",
                     template='plotly_dark', color='dot_color', color_discrete_map={'red': 'red', 'blue': 'blue'})
    
    fig.update_traces(textposition='top center', marker=dict(size=10))
    
    fig.update_traces(name='Jména')
    
    fig.update_layout(
        yaxis=dict(showticklabels=False, title=""),
        xaxis=dict(title="Datum narození", dtick="M12"),
        plot_bgcolor='#222',
        paper_bgcolor='#222',
        showlegend=False
    )
    
    return fig

if __name__ == '__main__':
    app.run_server(debug=True, host='127.0.0.1', port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
